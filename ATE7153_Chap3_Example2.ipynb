# %% [markdown]
# <a href="https://colab.research.google.com/github/wooihaw/ATE7153_T2530/blob/main/ATE7153_Chap3_Example2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ATE7153
# ## Chapter 3
# ### Example on Regression

# %%
import pandas as pd
from sklearn.model_selection import train_test_split as split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor

# %%
df = pd.read_csv("https://raw.githubusercontent.com/wooihaw/datasets/main/synchronous_machine.csv")
df.head()
# Out:
#     Iy    PF     e    dIf     If
# 0  3.0  0.66  0.34  0.383  1.563
# 1  3.0  0.68  0.32  0.372  1.552
# 2  3.0  0.70  0.30  0.360  1.540
# 3  3.0  0.72  0.28  0.338  1.518
# 4  3.0  0.74  0.26  0.317  1.497

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557 entries, 0 to 556
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Iy      557 non-null    float64
#  1   PF      557 non-null    float64
#  2   e       557 non-null    float64
#  3   dIf     557 non-null    float64
#  4   If      557 non-null    float64
# dtypes: float64(5)
# memory usage: 21.9 KB

# %%
df.isna().sum()
# Out:
# Iy     0
# PF     0
# e      0
# dIf    0
# If     0
# dtype: int64

# %%
X = df.drop(columns=['If'])
y = df['If']

X_train, X_test, y_train, y_test = split(X, y, test_size=0.25, random_state=42)

# %%
lnr = LinearRegression().fit(X_train, y_train)
print(f'lnr R2 score: {lnr.score(X_test, y_test):.3f}')
# Out:
# lnr R2 score: 1.000

# %%
knn = KNeighborsRegressor().fit(X_train, y_train)
print(f'knn R2 score: {knn.score(X_test, y_test):.3f}')
# Out:
# knn R2 score: 0.987
